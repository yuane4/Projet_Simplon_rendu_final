# %%
import pandas as pd
import numpy as np
import sklearn

# %%
df_sources = pd.read_excel('Sources.xlsx', encoding='latin-1')
df_991 = pd.read_excel('99-1.xlsx', encoding='latin-1')
df_199 = pd.read_excel('1-99.xlsx', encoding='latin-1')

# %%
from sklearn.model_selection import train_test_split 
#on divise l'échantillon en train et test 
X = df_sources['Adresses']
y = df_sources['Target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((207596,), (102250,), (207596,), (102250,))

# %% [markdown]
# ### modèle Naives Bayes en Multinomial

# %%
from sklearn.feature_extraction.text import CountVectorizer 
#on vectorize les données a étudier afin d'être comprise par le modèle
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train.astype('U'))
X_test_counts = count_vect.transform(X_test.astype('U'))
X_train_counts.shape, X_test_counts.shape
# Out:
# ((207596, 49636), (102250, 49636))

# %%
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB()
clf.fit(X_train_counts, y_train)

y_pred = clf.predict(X_test_counts)

# %%
from sklearn import metrics #on imprime les métrics d'évaluations
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y_test, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       1.00      0.99      0.99     67636
#      adresse       0.98      0.99      0.99     34614
#
#     accuracy                           0.99    102250
#    macro avg       0.99      0.99      0.99    102250
# weighted avg       0.99      0.99      0.99    102250
#
# accuracy of the model is : 0.990317848410758

# %% [markdown]
# ### Rajout de poids probabiliste en TF IDF

# %%
from sklearn.feature_extraction.text import TfidfTransformer 
#afin d'afiner le modèle, on instaur eun systèe de poids probabilitste en Tf -IDF

tf_transformer = TfidfTransformer(use_idf=False).fit(X_train_counts)
X_train_tf = tf_transformer.transform(X_train_counts)
X_test_tf = tf_transformer.transform(X_test_counts)
X_train_tf.shape, X_test_tf.shape
# Out:
# ((207596, 49636), (102250, 49636))

# %% [markdown]
# - #### Naîve Bayes Multinomial

# %%
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB()
clf.fit(X_train_tf, y_train)
y_pred = clf.predict(X_test_tf)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y_test, y_pred,  target_names=target_names))
print("accuracy of the model is :", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       1.00      0.99      0.99     67636
#      adresse       0.98      0.99      0.99     34614
#
#     accuracy                           0.99    102250
#    macro avg       0.99      0.99      0.99    102250
# weighted avg       0.99      0.99      0.99    102250
#
# accuracy of the model is : 0.9907677261613692

# %% [markdown]
# - #### Regression logistique

# %%
from sklearn.linear_model import LogisticRegression

Lr = LogisticRegression(random_state=0, max_iter = 100, solver = 'newton-cg')
Lr.fit(X_train_tf, y_train)
y_pred = Lr.predict(X_test_tf)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y_test, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       0.99      1.00      0.99     67636
#      adresse       1.00      0.98      0.99     34614
#
#     accuracy                           0.99    102250
#    macro avg       0.99      0.99      0.99    102250
# weighted avg       0.99      0.99      0.99    102250
#
# accuracy of the model is : 0.9915012224938875

# %% [markdown]
# - #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

Rf = RandomForestClassifier(max_depth=8, random_state=0)
Rf.fit(X_train_tf, y_train)
y_pred = Rf.predict(X_test_tf)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y_test, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       0.66      1.00      0.80     67636
#      adresse       1.00      0.01      0.02     34614
#
#     accuracy                           0.67    102250
#    macro avg       0.83      0.51      0.41    102250
# weighted avg       0.78      0.67      0.54    102250
#
# accuracy of the model is : 0.665760391198044

# %% [markdown]
# ### On change de dataset avec une répartion 99% adresses 1% de bruit

# %%
from sklearn.model_selection import train_test_split 
#on divise l'échantillon en train et test 
X = df_991['Adresses']
y = df_991['Target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=44)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((67000,), (33001,), (67000,), (33001,))

# %%
from sklearn.feature_extraction.text import CountVectorizer #on vectorize les données a étudier afin d'être comprise par le modèle
count_vect = CountVectorizer()
X_tr991_counts = count_vect.fit_transform(X_train.astype('U'))
X_te991_counts = count_vect.transform(X_test.astype('U'))
X_tr991_counts.shape, X_te991_counts.shape
# Out:
# ((67000, 35458), (33001, 35458))

# %%
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB(alpha =  0.00001, fit_prior = True) #alpha = 1.2 fit_prior = False
# clf = MultinomialNB()
clf.fit(X_tr991_counts, y_train)

y_pred = clf.predict(X_te991_counts )

# %%
from sklearn import metrics #on imprime les métrics d'évaluations
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y_test, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       1.00      0.34      0.51       296
#      adresse       0.99      1.00      1.00     32705
#
#     accuracy                           0.99     33001
#    macro avg       1.00      0.67      0.75     33001
# weighted avg       0.99      0.99      0.99     33001
#
# accuracy of the model is : 0.9940607860367867

# %% [markdown]
# ### Avec TF IDF

# %%
from sklearn.feature_extraction.text import TfidfTransformer #afin d'afiner le modèle, on instaur eun systèe de poids probabilitste en Tf -IDF

tf_transformer = TfidfTransformer(use_idf=False).fit(X_tr991_counts)
X_tr991_tf = tf_transformer.transform(X_tr991_counts)
X_te991_tf = tf_transformer.transform(X_te991_counts)
X_tr991_tf.shape, X_te991_tf.shape
# Out:
# ((67000, 35458), (33001, 35458))

# %%
import pickle
# load the model from disk

gb = pickle.load(open("gb.pkl", "rb"))
gb.fit(X_tr991_tf, y_train)
pickle.dump(gb, open('gb.pkl', 'wb'))
y_pred = gb.predict(X_te991_tf)

# %%
from sklearn import metrics #on imprime les métrics d'évaluations
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y_test, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       0.99      0.44      0.61       296
#      adresse       0.99      1.00      1.00     32705
#
#     accuracy                           0.99     33001
#    macro avg       0.99      0.72      0.80     33001
# weighted avg       0.99      0.99      0.99     33001
#
# accuracy of the model is : 0.9949092451743886

# %%
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB(alpha =  0.00001, fit_prior = True) #alpha = 1.2 fit_prior = False
# clf = MultinomialNB()
clf.fit(X_tr991_tf, y_train)

y_pred = clf.predict(X_te991_tf)

# %%
from sklearn import metrics #on imprime les métrics d'évaluations
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y_test, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       0.99      0.34      0.51       296
#      adresse       0.99      1.00      1.00     32705
#
#     accuracy                           0.99     33001
#    macro avg       0.99      0.67      0.75     33001
# weighted avg       0.99      0.99      0.99     33001
#
# accuracy of the model is : 0.9940607860367867

# %% [markdown]
# - #### Regression Logistique

# %%
from sklearn.linear_model import LogisticRegression

Lr = LogisticRegression(random_state=0)
Lr.fit(X_tr991_tf, y_train)
y_pred = Lr.predict(X_te991_tf)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y_test, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       1.00      0.31      0.48       296
#      adresse       0.99      1.00      1.00     32705
#
#     accuracy                           0.99     33001
#    macro avg       1.00      0.66      0.74     33001
# weighted avg       0.99      0.99      0.99     33001
#
# accuracy of the model is : 0.9938486712523863

# %% [markdown]
# - #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

Rf = RandomForestClassifier(max_depth=10, random_state=0, n_estimators=100)
Rf.fit(X_tr991_tf, y_train)
y_pred = Rf.predict(X_te991_tf)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y_test, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       1.00      0.01      0.01       296
#      adresse       0.99      1.00      1.00     32705
#
#     accuracy                           0.99     33001
#    macro avg       1.00      0.50      0.50     33001
# weighted avg       0.99      0.99      0.99     33001
#
# accuracy of the model is : 0.9910911790551802

# %% [markdown]
# ### On change de dataset avec une répartion 1% adresses 99% de bruit

# %%
from sklearn.model_selection import train_test_split 
#on divise l'échantillon en train et test 
X = df_199['Adresses']
y = df_199['Target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=44)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((66999,), (33000,), (66999,), (33000,))

# %%
from sklearn.feature_extraction.text import CountVectorizer #on vectorize les données a étudier afin d'être comprise par le modèle
count_vect = CountVectorizer()
X_tr199_counts = count_vect.fit_transform(X_train.astype('U'))
X_te199_counts = count_vect.transform(X_test.astype('U'))
X_tr199_counts.shape, X_te199_counts.shape
# Out:
# ((66999, 16477), (33000, 16477))

# %% [markdown]
# - #### Naïve Bayes Multinomial

# %%
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB()
clf.fit(X_tr199_counts , y_train)

y_pred = clf.predict(X_te199_counts)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y_test, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       1.00      1.00      1.00     32685
#      adresse       1.00      0.88      0.94       315
#
#     accuracy                           1.00     33000
#    macro avg       1.00      0.94      0.97     33000
# weighted avg       1.00      1.00      1.00     33000
#
# accuracy of the model is : 0.9988484848484849

# %% [markdown]
# - #### Regression logistique

# %%
from sklearn.linear_model import LogisticRegression

Lr = LogisticRegression(random_state=0)
Lr.fit(X_tr199_counts, y_train)
y_pred = Lr.predict(X_te199_counts)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y_test, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       1.00      1.00      1.00     32685
#      adresse       1.00      0.72      0.84       315
#
#     accuracy                           1.00     33000
#    macro avg       1.00      0.86      0.92     33000
# weighted avg       1.00      1.00      1.00     33000
#
# accuracy of the model is : 0.9973030303030304

# %% [markdown]
# - #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

Rf = RandomForestClassifier(max_depth=8, random_state=0)
Rf.fit(X_tr199_counts, y_train)
y_pred = Rf.predict(X_te199_counts)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y_test, y_pred, target_names=target_names, zero_division = 0))
print("accuracy of the model is :", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       0.99      1.00      1.00     32685
#      adresse       0.00      0.00      0.00       315
#
#     accuracy                           0.99     33000
#    macro avg       0.50      0.50      0.50     33000
# weighted avg       0.98      0.99      0.99     33000
#
# accuracy of the model is : 0.9904545454545455

# %% [markdown]
# ### Entrainement sur une répartition 50 -50 et 1 millionss de lignes

# %% [markdown]
# - chargement des données :

# %%
df_ad = pd.read_excel('adresses_50_50_am.xlsx', encoding='latin-1')
df_bruit = pd.read_excel('bruit.xlsx', encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9c4ee188f728> in <module>
# ----> 1 df_ad = pd.read_excel('adresses_50_50_am.xlsx', encoding='latin-1')
#       2 df_bruit = pd.read_excel('bruit.xlsx', encoding='latin-1')
#
# NameError: name 'pd' is not defined

# %%
df_50_50 = pd.concat([df_ad, df_bruit])

# %%
df_50_50=sklearn.utils.shuffle(df_50_50)

# %%
from sklearn.model_selection import train_test_split 
#on divise l'échantillon en train et test 
X = df_50_50['Adresses']
y = df_50_50['Target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((683004,), (336406,), (683004,), (336406,))

# %%
from sklearn.feature_extraction.text import CountVectorizer 
import pickle
#on vectorize les données a étudier afin d'être comprise par le modèle
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train.astype('U'))
vectorize = count_vect
pickle.dump(vectorize,open("vectorizer.pkl","wb"))
X_test_counts = count_vect.transform(X_test.astype('U'))
X_train_counts.shape, X_test_counts.shape
# Out:
# ((683004, 279659), (336406, 279659))

# %%
from sklearn.feature_extraction.text import TfidfTransformer 
#afin d'afiner le modèle, on instaur eun systèe de poids probabilitste en Tf -IDF

tf_transformer = TfidfTransformer(use_idf=False).fit(X_train_counts)
X_train_tf = tf_transformer.transform(X_train_counts)
X_test_tf = tf_transformer.transform(X_test_counts)
X_train_tf.shape, X_test_tf.shape
# Out:
# ((683004, 279659), (336406, 279659))

# %%
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB(alpha = 0.001, fit_prior = False)
clf = clf.fit(X_train_tf, y_train)

y_pred = clf.predict(X_test_tf)

# %%
from sklearn import metrics #on imprime les métrics d'évaluations
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y_test, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       1.00      0.95      0.97    166234
#      adresse       0.95      1.00      0.98    170172
#
#     accuracy                           0.97    336406
#    macro avg       0.98      0.97      0.97    336406
# weighted avg       0.98      0.97      0.97    336406
#
# accuracy of the model is : 0.9744951041301285

# %%
metrics.confusion_matrix(y_test, y_pred)
# Out:
# array([[157709,   8525],
#        [    55, 170117]], dtype=int64)

# %%
from sklearn.model_selection import cross_val_score

X = X_train_tf
y = y_train

scores = cross_val_score(MultinomialNB(alpha = 0.001, fit_prior = False), X, y, cv=8)
print("Cross-validation scores: {}".format(scores))
# Out:
# Cross-validation scores: [0.97487584 0.97405594 0.97443075 0.97481728 0.97461786 0.97499268
#  0.97488726 0.97412592]

# %%
from sklearn.model_selection import GridSearchCV
import time
parameters = {'alpha': (3,2,1, 0.1, 0.01, 0.001, 0.0001, 0.00001, 0.000001), 'fit_prior' : (True, False)}
gs_clf = GridSearchCV(MultinomialNB(), parameters, cv=5, n_jobs=-1)
gs_clf.fit(X, y)  
#print("done in {0}s".format(time() - t0))  
print("Best score: {0}".format(gs_clf.best_score_))  
print("Best parameters set:")  
best_parameters = gs_clf.best_estimator_.get_params()
for param_name in sorted(list(parameters.keys())):  
            print("\t{0}: {1}".format(param_name, best_parameters[param_name]))
# Out:
# Best score: 0.9748771603094565
# Best parameters set:
# 	alpha: 0.001
# 	fit_prior: False

# %%
from sklearn.linear_model import LogisticRegression

Lr = LogisticRegression(random_state=0, max_iter = 150, solver = 'lbfgs', class_weight = 'balanced', C = 1.2)
Lr = Lr.fit(X_train_tf, y_train)
y_pred = Lr.predict(X_test_tf)

# %%
from sklearn import metrics #on imprime les métrics d'évaluations
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y_test, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       0.99      1.00      0.99    166234
#      adresse       1.00      0.99      0.99    170172
#
#     accuracy                           0.99    336406
#    macro avg       0.99      0.99      0.99    336406
# weighted avg       0.99      0.99      0.99    336406
#
# accuracy of the model is : 0.9934454201173581

# %%
metrics.confusion_matrix(y_test, y_pred)
# Out:
# array([[166156,    106],
#        [   169, 169975]])

# %%
from sklearn.model_selection import cross_val_score

X = X_train_tf
y = y_train

scores = cross_val_score(LogisticRegression(random_state=0, max_iter = 150, solver = 'lbfgs', class_weight = 'blanced', C = 1.2), X, y, cv=8)
print("Cross-validation scores: {}".format(scores))
# Out:
# C:\LOGICIELS\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# C:\LOGICIELS\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# Cross-validation scores: [0.99310111 0.9932768  0.99365161 0.99279657 0.99310102 0.99318302
#  0.99354612 0.99333529]

# %%
from sklearn.model_selection import GridSearchCV
import time
parameters = {'solver': ('newton-cg', 'lbfgs', 'sag', 'saga'), 'max_iter' : (10, 50, 100, 150, 200), 'class_weight' : ('dict', 'balanced', None), 'C' : (0.1, 1.0, 1.2, 0.5)}
gs_clf = GridSearchCV(LogisticRegression(), parameters, cv=5, n_jobs=-1)
gs_clf.fit(X, y)  
#print("done in {0}s".format(time() - t0))  
print("Best score: {0}".format(gs_clf.best_score_))  
print("Best parameters set:")  
best_parameters = gs_clf.best_estimator_.get_params()
for param_name in sorted(list(parameters.keys())):  
            print("\t{0}: {1}".format(param_name, best_parameters[param_name]))
# Out:
# Best score: 0.9931288835790127
# Best parameters set:
# 	C: 1.2
# 	class_weight: balanced
# 	max_iter: 50
# 	solver: lbfgs
# C:\LOGICIELS\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
from sklearn.ensemble import RandomForestClassifier

Rf = RandomForestClassifier(max_depth=8, random_state=0, n_estimators = 350, bootstrap = True, max_features = 'auto', min_samples_split = 5)
Rf = Rf.fit(X_train_tf, y_train)
y_pred = Rf.predict(X_test_tf)

# %%
from sklearn import metrics #on imprime les métrics d'évaluations
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y_test, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       0.95      0.99      0.97    166234
#      adresse       0.99      0.95      0.97    170172
#
#     accuracy                           0.97    336406
#    macro avg       0.97      0.97      0.97    336406
# weighted avg       0.97      0.97      0.97    336406
#
# accuracy of the model is : 0.967842428494141

# %%
metrics.confusion_matrix(y_test, y_pred)
# Out:
# array([[159151,   6600],
#        [ 12999, 157656]], dtype=int64)

# %%
from sklearn.model_selection import cross_val_score

X = X_train_tf
y = y_train

scores = cross_val_score(RandomForestClassifier(max_depth=8, random_state=0, n_estimators = 350, bootstrap = True, max_features = 'auto', min_samples_split = 5), X, y, cv=8)  
print("Cross-validation scores: {}".format(scores))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-cc30050493f4> in <module>
#       4 y = y_train
#       5
# ----> 6 scores = cross_val_score(RandomForestClassifier(max_depth=8, random_state=0, n_estimators = 350, bootstrap = True, max_features = 'auto', min_samples_split = 5), X, y, cv=8)
#       7 print("Cross-validation scores: {}".format(scores))
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     387                                 fit_params=fit_params,
#     388                                 pre_dispatch=pre_dispatch,
# --> 389                                 error_score=error_score)
#     390     return cv_results['test_score']
#     391
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     229             return_times=True, return_estimator=return_estimator,
#     230             error_score=error_score)
# --> 231         for train, test in cv.split(X, y, groups))
#     232
#     233     zipped_scores = list(zip(*scores))
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     919             # remaining jobs.
#     920             self._iterating = False
# --> 921             if self.dispatch_one_batch(iterator):
#     922                 self._iterating = self._original_iterator is not None
#     923
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     512             estimator.fit(X_train, **fit_params)
#     513         else:
# --> 514             estimator.fit(X_train, y_train, **fit_params)
#     515
#     516     except Exception as e:
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     328                     t, self, X, y, sample_weight, i, len(trees),
#     329                     verbose=self.verbose, class_weight=self.class_weight)
# --> 330                 for i, t in enumerate(trees))
#     331
#     332             # Collect newly grown trees
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     116             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     117
# --> 118         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     119     else:
#     120         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     814             sample_weight=sample_weight,
#     815             check_input=check_input,
# --> 816             X_idx_sorted=X_idx_sorted)
#     817         return self
#     818
#
# C:\LOGICIELS\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     378                                            min_impurity_split)
#     379
# --> 380         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     381
#     382         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
from sklearn.model_selection import GridSearchCV
import time
parameters = {'n_estimators': (100, 150, 200, 300, 350), 'max_depth' : (3, 5, 8, 12), 'max_features' : ('auto', 'sqrt'), 'min_samples_split' : (2, 5, 10), 'bootstrap' : (True, False)}
gs_clf = GridSearchCV(RandomForestClassifier(), parameters, cv=5, n_jobs=-1)
gs_clf.fit(X, y)  
#print("done in {0}s".format(time() - t0))  
print("Best score: {0}".format(gs_clf.best_score_))  
print("Best parameters set:")  
best_parameters = gs_clf.best_estimator_.get_params()
for param_name in sorted(list(parameters.keys())):  
            print("\t{0}: {1}".format(param_name, best_parameters[param_name]))
# Out:
# Best score: 0.9944846587591354
# Best parameters set:
# 	bootstrap: True
# 	max_depth: 8
# 	max_features: auto
# 	min_samples_split: 5
# 	n_estimators: 350

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=8, random_state=0)
gb = gb.fit(X_train_tf, y_train)
y_pred = gb.predict(X_test_tf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6a7f3453a3e3> in <module>
#       2
#       3 gb = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=8, random_state=0)
# ----> 4 gb = gb.fit(X_train_tf, y_train)
#       5 y_pred = gb.predict(X_test_tf)
#
# NameError: name 'X_train_tf' is not defined

# %%
X_train_tf.shape
# Out:
# (683004, 249548)

# %%
from sklearn import metrics #on imprime les métrics d'évaluations
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y_test, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-bae22ed3b223> in <module>
#       3
#       4 target_names = ['bruit', 'adresse']
# ----> 5 print(metrics.classification_report(y_test, y_pred, target_names=target_names))
#       6 print("accuracy of the model is :", accuracy_score(y_test, y_pred))
#
# NameError: name 'y_test' is not defined

# %%
import pickle

pickle.dump(clf, open('nbm.pkl', 'wb'))
pickle.dump(Lr, open('Lr.pkl', 'wb'))
pickle.dump(Rf, open('Rf.pkl', 'wb'))
pickle.dump(gb, open('gb.pkl', 'wb'))

# %% [markdown]
# ### Répartition 99 vs 1

# %%
# df_991
# df_199

X = df_991['Adresses']
y = df_991['Target']

# %%
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.feature_extraction.text import TfidfTransformer
import pickle

vectorisation = pickle.load(open("vectorizer.pkl", "rb"))
X_counts = vectorisation.transform(X.astype('U'))

tf_transformer = TfidfTransformer(use_idf=False).fit(X_counts)
X_tf = tf_transformer.transform(X_counts)

X_tf.shape, y.shape
# Out:
# ((100001, 279659), (100001,))

# %%
import pickle
# load the model from disk

nbm = pickle.load(open("nbm.pkl", "rb"))
y_pred = nbm.predict(X_tf)

# %%
from sklearn import metrics #on imprime les métrics d'évaluations
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       0.79      0.83      0.81      1002
#      adresse       1.00      1.00      1.00     98999
#
#     accuracy                           1.00    100001
#    macro avg       0.90      0.92      0.91    100001
# weighted avg       1.00      1.00      1.00    100001
#
# accuracy of the model is : 0.996160038399616

# %%
X_tf.shape
# Out:
# (100001, 279689)

# %%
import pickle
# load the model from disk

rf = pickle.load(open("Rf.pkl", "rb"))
y_pred = rf.predict(X_tf)

# %%
from sklearn import metrics #on imprime les métrics d'évaluations
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       0.10      0.91      0.17      1002
#      adresse       1.00      0.91      0.95     98999
#
#     accuracy                           0.91    100001
#    macro avg       0.55      0.91      0.56    100001
# weighted avg       0.99      0.91      0.95    100001
#
# accuracy of the model is : 0.9123108768912311

# %%
import pickle
# load the model from disk

lr = pickle.load(open("Lr.pkl", "rb"))
y_pred = lr.predict(X_tf)

# %%
from sklearn import metrics #on imprime les métrics d'évaluations
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       0.29      1.00      0.45      1002
#      adresse       1.00      0.98      0.99     98999
#
#     accuracy                           0.98    100001
#    macro avg       0.65      0.99      0.72    100001
# weighted avg       0.99      0.98      0.98    100001
#
# accuracy of the model is : 0.9755602443975561

# %%
import pickle
# load the model from disk

gb = pickle.load(open("gb.pkl", "rb"))
y_pred = gb.predict(X_tf)

# %%
from sklearn import metrics #on imprime les métrics d'évaluations
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       0.25      1.00      0.40      1002
#      adresse       1.00      0.97      0.98     98999
#
#     accuracy                           0.97    100001
#    macro avg       0.62      0.98      0.69    100001
# weighted avg       0.99      0.97      0.98    100001
#
# accuracy of the model is : 0.9696403035969641

# %% [markdown]
# ### Répartition 1 vs 99

# %%
from sklearn.model_selection import train_test_split 

# df_991
# df_199

X = df_199['Adresses']
y = df_199['Target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((66999,), (33000,), (66999,), (33000,))

# %%
X_train_counts = count_vect.fit_transform(X_train.astype('U'))
X_test_counts = count_vect.transform(X_test.astype('U'))
X_train_counts.shape, X_test_counts.shape
# Out:
# ((66999, 16300), (33000, 16300))

# %%
y.shape
# Out:
# (99999,)

# %%
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.feature_extraction.text import TfidfTransformer
import pickle

vectorisation = pickle.load(open("vectorizer.pkl", "rb"))
X_counts5050 = vectorisation.transform(X.astype('U'))
X_ctr = vectorisation.transform(X_train.astype('U'))
X_cte= vectorisation.transform(X_test.astype('U'))
tf_transformer = TfidfTransformer(use_idf=False).fit(X_counts5050)
X_tf5050 = tf_transformer.transform(X_counts5050)

X_tf5050.shape, y.shape, X_ctr.shape, X_cte.shape
# Out:
# ((99999, 279659), (99999,), (66999, 279659), (33000, 279659))

# %%
import pickle
# load the model from disk

nbm = pickle.load(open("nbm.pkl", "rb"))
y_pred = nbm.predict(X_tf5050)

# %%
from sklearn import metrics #on imprime les métrics d'évaluations
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       1.00      0.80      0.89     98999
#      adresse       0.05      1.00      0.09      1000
#
#     accuracy                           0.81     99999
#    macro avg       0.52      0.90      0.49     99999
# weighted avg       0.99      0.81      0.88     99999
#
# accuracy of the model is : 0.8068280682806828

# %%
import pickle
# load the model from disk

rf = pickle.load(open("Rf.pkl", "rb"))
y_pred = rf.predict(X_tf5050)

# %%
from sklearn import metrics #on imprime les métrics d'évaluations
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       1.00      0.92      0.96     98999
#      adresse       0.10      0.90      0.18      1000
#
#     accuracy                           0.92     99999
#    macro avg       0.55      0.91      0.57     99999
# weighted avg       0.99      0.92      0.95     99999
#
# accuracy of the model is : 0.9170591705917059

# %%
import pickle
# load the model from disk

lr = pickle.load(open("Lr.pkl", "rb"))
y_pred = lr.predict(X_tf5050)

# %%
from sklearn import metrics #on imprime les métrics d'évaluations
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       1.00      0.97      0.98     98999
#      adresse       0.23      0.96      0.37      1000
#
#     accuracy                           0.97     99999
#    macro avg       0.61      0.97      0.68     99999
# weighted avg       0.99      0.97      0.98     99999
#
# accuracy of the model is : 0.967139671396714

# %%
import pickle
# load the model from disk

gb = pickle.load(open("gb.pkl", "rb"))
gb_model = gb.fit(X_ctr, y_train)
pickle.dump(gb_model, open('gb.pkl', 'wb'))

y_pred = gb_model.predict(X_cte)

# %%
from sklearn import metrics #on imprime les métrics d'évaluations
from sklearn.metrics import accuracy_score

target_names = ['bruit', 'adresse']
print(metrics.classification_report(y_test, y_pred, target_names=target_names))
print("accuracy of the model is :", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        bruit       1.00      1.00      1.00     32653
#      adresse       0.99      0.92      0.96       347
#
#     accuracy                           1.00     33000
#    macro avg       0.99      0.96      0.98     33000
# weighted avg       1.00      1.00      1.00     33000
#
# accuracy of the model is : 0.9990909090909091

# %%
Le modèle en python qui ressort avec les meilleurs résultats quelque soit la répartition est le Gradient Boost en clasification
